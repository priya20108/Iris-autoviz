# %%
pip install autoviz

# %%
pip install pyforest

# %%
import pyforest
import autoviz
import warnings
warnings.filterwarnings('ignore')
df=pd.read_csv('/content/Iris.csv')
#importing Autoviz class
from autoviz.AutoViz_Class import AutoViz_Class#Instantiate the AutoViz class
AV = AutoViz_Class()

df
# Out:
#       Id  SepalLengthCm  ...  PetalWidthCm         Species
# 0      1            5.1  ...           0.2     Iris-setosa
# 1      2            4.9  ...           0.2     Iris-setosa
# 2      3            4.7  ...           0.2     Iris-setosa
# 3      4            4.6  ...           0.2     Iris-setosa
# 4      5            5.0  ...           0.2     Iris-setosa
# ..   ...            ...  ...           ...             ...
# 145  146            6.7  ...           2.3  Iris-virginica
# 146  147            6.3  ...           1.9  Iris-virginica
# 147  148            6.5  ...           2.0  Iris-virginica
# 148  149            6.2  ...           2.3  Iris-virginica
# 149  150            5.9  ...           1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %%
df=df.drop(["Id"],axis=1)

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
gf=df.groupby("Species")
#gf.reset_index(inplace=True)
gf

# %%
gf.describe().T
# Out:
# Species              Iris-setosa  Iris-versicolor  Iris-virginica
# SepalLengthCm count    50.000000        50.000000       50.000000
#               mean      5.006000         5.936000        6.588000
#               std       0.352490         0.516171        0.635880
#               min       4.300000         4.900000        4.900000
#               25%       4.800000         5.600000        6.225000
#               50%       5.000000         5.900000        6.500000
#               75%       5.200000         6.300000        6.900000
#               max       5.800000         7.000000        7.900000
# SepalWidthCm  count    50.000000        50.000000       50.000000
#               mean      3.418000         2.770000        2.974000
#               std       0.381024         0.313798        0.322497
#               min       2.300000         2.000000        2.200000
#               25%       3.125000         2.525000        2.800000
# ...

# %%
gf.head()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm          Species
# 0              5.1           3.5            1.4           0.2      Iris-setosa
# 1              4.9           3.0            1.4           0.2      Iris-setosa
# 2              4.7           3.2            1.3           0.2      Iris-setosa
# 3              4.6           3.1            1.5           0.2      Iris-setosa
# 4              5.0           3.6            1.4           0.2      Iris-setosa
# 50             7.0           3.2            4.7           1.4  Iris-versicolor
# 51             6.4           3.2            4.5           1.5  Iris-versicolor
# 52             6.9           3.1            4.9           1.5  Iris-versicolor
# 53             5.5           2.3            4.0           1.3  Iris-versicolor
# 54             6.5           2.8            4.6           1.5  Iris-versicolor
# 100            6.3           3.3            6.0           2.5   Iris-virginica
# ...

# %%
#average sepal length of various species
sns.set(rc = {'figure.figsize':(5,8)})
species=df["Species"]
sepalen=df["SepalLengthCm"]
sns.barplot(species,sepalen,data=df)
plt.show()

# %%
#average petal length of various species
fig = plt.figure(figsize = (5, 5))
species=df["Species"]
petalen=df["PetalLengthCm"]
# creating the bar plot
plt.bar(species,petalen)
 
plt.xlabel("Species")
plt.ylabel("PetalLengthCm")
plt.title("average petal length of various species")
plt.show()

# %%
#2D scatter plot
df.plot(kind="scatter",x="SepalLengthCm",y="SepalWidthCm")
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %% [markdown]
# In the above figure, we are’t able to understand which is setosa or versicolor or virginica flower because all points are in same colour. It cannot make much sense out it

# %%
#  2-D Scatter plot with colour for each flower.
sns.set_style("whitegrid");
sns.FacetGrid(df,hue="Species",size=4) \
    .map(plt.scatter,"SepalLengthCm","SepalWidthCm") \
    .add_legend()
plt.show()

# %% [markdown]
# Observation(s) | Conclusion
# Blue points can be easily separated from red and green by drawing a line.
# But red and green data points cannot be easily separated.
# Using sepal_length and sepal_width features, we can distinguish Setosa flowers from others.
# Separating Versicolor from Viginica is much harder as they have considerable overlap.

# %%
#3d scatter plot
import plotly.express as px
fig = px.scatter_3d(df, x='SepalLengthCm', y='SepalWidthCm', z='PetalWidthCm',color='Species')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c5ef76f8-fb71-48a2-85c8-257a1b50b05b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c5ef76f8-fb71-48a2-85c8-257a1b50b05b")) {
#                     Plotly.newPlot(
#                         'c5ef76f8-fb71-48a2-85c8-257a1b50b05b',
# ...

# %% [markdown]
#  Using plotly library for plotting , sepal length on the x-axis, sepal width on the y-axis and petal length on the z-axis.

# %%
#pairplot
sns.set_style("whitegrid");
sns.pairplot(df,hue="Species",size=3);
plt.show()

# %% [markdown]
# petal length and petal width are the most useful features to identify various flower types.
# Where Setosa can be easily identified (linearly separable), virginica and Versicolor have some overlap (almost linearly separable).

# %%
# A vertical boxplot of sepal lenght  grouped by various species:
sns.set_style("whitegrid")
  
sns.boxplot(x ='Species', y ='SepalLengthCm', data =df)

# %% [markdown]
# take the first box plot i.e, blue box plot of the figure and understand these statistical things:
# *Bottom black horizontal line of blue box plot is minimum value
# *First black horizontal line of rectangle shape of blue box plot is First
#  quartile or 25%
# *Second black horizontal line of rectangle shape of blue box plot is Second     quartile or 50% or median.
# *Third black horizontal line of rectangle shape of blue box plot is third quartile or 75%
# *Top black horizontal line of rectangle shape of blue box plot is maximum value.
# *Small diamond shape of blue box plot is outlier data or erroneous data
# *By obsarving it we can say setosa has less sepal lenght then versicolor and verginica

# %%
# A vertical boxplot fot petal lenght  grouped by various species:
sns.set_style("whitegrid")
  
sns.boxplot(x ='Species', y ='PetalLengthCm', data=df)

# %% [markdown]
# box plot is especially useful for indicating whether a distribution is skewed and whether there are potential unusual observations (outliers) in the data set.
# Now we can say that Satosa has less petal length
# Virginica and Versicolor both have slightly closer patel length.

# %%
#violinplot for visualizing petal length for various species
sns.violinplot(x="Species",y="PetalLengthCm", data=df, size=8)
plt.show()

# %% [markdown]
# A violin plot is a method of plotting numeric data. It is similar to a box plot, with the addition of a rotated kernel density plot on each side. Violin plots are similar to box plots, except that they also show the probability density of the data at different values, usually smoothed by a kernel density estimator.

# %%
df = AV.AutoViz('/content/Iris.csv')
# Out:
# Shape of your Data Set loaded: (150, 6)
# ############## C L A S S I F Y I N G  V A R I A B L E S  ####################
# Classifying variables in data set...
#     Number of Numeric Columns =  4
#     Number of Integer-Categorical Columns =  0
#     Number of String-Categorical Columns =  1
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  0
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  0
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  1
#     Number of Columns to Delete =  0
#     6 Predictors classified...
#         This does not include the Target column(s)
#         1 variables removed since they were ID or low-information variables
# Number of All Scatter Plots = 10
# Time to run AutoViz (in seconds) = 7.193
#
#  ###################### VISUALIZATION Completed ########################

# %%
df=df.drop(["Species"],axis=1)
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]

# %%
#heatmap for iris datdset
sns.set(rc = {'figure.figsize':(20,12)})
sns.heatmap(df)

# %%
#heatmap showing correlation between various features
sns.set(rc = {'figure.figsize':(15,8)})
sns.heatmap(df.corr())

# %% [markdown]
# Heatmap is a graphical way to visualize visitor behavior data in the form of hot and cold spots employing a warm-to-cool color scheme. The warm colors indicated sections with the most visitor interaction, red being the area of highest interaction, and the cool colors indicate sections with the lowest interaction

# %% [markdown]
# After doing Eda we are now able to understand the data and the important features completely so we are ready to apply machine learning model on it. You can get all above code from
